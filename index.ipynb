# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
#
# In this lab, you'll practice your scraping skills on an online music magazine and events website called Resident Advisor.
#
# ## Objectives
#
# You will be able to:
# * Create a full scraping pipeline that involves traversing over many pages of a website, dealing with errors and storing data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://ra.co website. For reproducibility we will use the [Internet Archive](https://archive.org/) Wayback Machine to retrieve a version of this page from March 2019.
#
# Start by navigating to the events page [here](https://web.archive.org/web/20210325230938/https://ra.co/events/us/newyork?week=2019-03-30) in your browser. It should look something like this:
#
# <img src="images/ra_top.png">

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page
#
# The function should return a Pandas DataFrame with columns for the `Event_Name`, `Venue`, and `Number_of_Attendees`.
#
# Start by importing the relevant libraries, making a request to the relevant URL, and exploring the contents of the response with `BeautifulSoup`. Then fill in the `scrape_events` function with the relevant code.

# %%
# Relevant imports
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re
import numpy as np

# %%
EVENTS_PAGE_URL = "https://web.archive.org/web/20210326225933/https://ra.co/events/us/newyork?week=2019-03-30"

# Exploration: making the request and parsing the response
url = "https://web.archive.org/web/20210326225933/https://ra.co/events/us/newyork?week=2019-03-30"
html_page = requests.get(url) 
soup = BeautifulSoup(html_page.content, 'html.parser')
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html lang="en"><head><script src="//archive.org/includes/analytics.js?v=cf34f82" type="text/javascript"></script>
# <script type="text/javascript">window.addEventListener('DOMContentLoaded',function(){var v=archive_analytics.values;v.service='wb';v.server_name='wwwb-app203.us.archive.org';v.server_ms=417;archive_analytics.send_pageview({});});</script>
# <script charset="utf-8" src="/_static/js/bundle-playback.js?v=UfTkgsKx" type="text/javascript"></script>
# <script charset="utf-8" src="/_static/js/wombat.js?v=UHAOicsW" type="text/javascript"></script>
# <script type="text/javascript">
#   __wm.init("https://web.archive.org/web");
#   __wm.wombat("https://ra.co/events/us/newyork?week=2019-03-30","20210326225933","https://web.archive.org/","web","/_static/",
# 	      "1616799573");
# </script>
# <link href="/_static/css/banner-styles.css?v=omkqRugM" rel="stylesheet" type="text/css"/>
# <link href="/_static/css/iconochive.css?v=qtvMKcIJ" rel="stylesheet" type="text/css"/>
# <!-- End Wayback Rewrite JS Include -->
# <script>
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://web.archive.org/web/20210326225933/https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-MDN5X6X')
# </script><link href="/web/20210326225933im_/https://ra.co/static/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/><link href="/web/20210326225933im_/https://ra.co/static/favicon.svg" rel="icon" type="image/svg+xml"/><link href="/web/20210326225933im_/https://ra.co/static/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/><link href="/web/20210326225933im_/https://ra.co/static/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/><link color="#ff4848" href="/web/20210326225933im_/https://ra.co/static/safari-pinned-tab.svg" rel="mask-icon"/><link href="/web/20210326225933/https://ra.co/static/site.webmanifest" rel="manifest"/><meta content="Resident Advisor" name="apple-mobile-web-app-title"/><meta content="Resident Advisor" name="application-name"/><meta content="#ff4848" name="msapplication-TileColor"/><meta content="#000000" name="theme-color"/><link href="https://web.archive.org/web/20210326225933/https://securepubads.g.doubleclick.net/" rel="preconnect"/><link href="https://web.archive.org/web/20210326225933/https://securepubads.g.doubleclick.net/" rel="dns-prefetch"/><link href="https://web.archive.org/web/20210326225933/https://z.moatads.com/" rel="preconnect"/><link href="https://web.archive.org/web/20210326225933/https://z.moatads.com/" rel="dns-prefetch"/><link href="https://web.archive.org/web/20210326225933/https://www.google.com/" rel="preconnect"/><link href="https://web.archive.org/web/20210326225933/https://www.google.com/" rel="dns-prefetch"/><link href="https://web.archive.org/web/20210326225933/https://adservice.google.com/" rel="preconnect"/><link href="https://web.archive.org/web/20210326225933/https://adservice.google.com/" rel="dns-prefetch"/><link href="https://web.archive.org/web/20210326225933/https://adservice.google.co.uk/" rel="preconnect"/><link href="https://web.archive.org/web/20210326225933/https://adservice.google.co.uk/" rel="dns-prefetch"/><link href="https://web.archive.org/web/20210326225933/https://www.googletagservices.com/" rel="preconnect"/><link href="https://web.archive.org/web/20210326225933/https://www.googletagservices.com/" rel="dns-prefetch"/><link href="https://web.archive.org/web/20210326225933/https://www.google-analytics.com/" rel="preconnect"/><link href="https://web.archive.org/web/20210326225933/https://www.google-analytics.com/" rel="dns-prefetch"/><link href="https://web.archive.org/web/20210326225933/https://tpc.googlesyndication.com/" rel="preconnect"/><link href="https://web.archive.org/web/20210326225933/https://tpc.googlesyndication.com/" rel="dns-prefetch"/><link href="https://web.archive.org/web/20210326225933/https://pagead2.googlesyndication.com/" rel="preconnect"/><link href="https://web.archive.org/web/20210326225933/https://pagead2.googlesyndication.com/" rel="dns-prefetch"/><link href="https://web.archive.org/web/20210326225933/https://www.googletagmanager.com/" rel="preconnect"/><link href="https://web.archive.org/web/20210326225933/https://www.googletagmanager.com/" rel="dns-prefetch"/><meta charset="utf-8"/><meta content="summary_large_image" name="twitter:card"/><meta content="@residentadvisor" name="twitter:site"/><meta content="712773712080127" property="fb:app_id"/><meta content="https://web.archive.org/web/20210326225933im_/https://im.ra.co/images/ra-co-logo.jpg" property="og:image"/><meta content="Resident Advisor" property="og:site_name"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/><link as="font" crossorigin="anonymous" href="/web/20210326225933/https://ra.co/static/AlternateGothicPro.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="/web/20210326225933/https://ra.co/static/RobotoMono-Regular.woff2" rel="preload" type="font/woff2"/><title>Events · New York ⟋ RA</title><meta content="index,follow" name="robots"/><meta content="index,follow" name="googlebot"/><meta content="RA: Resident Advisor" name="description"/><meta content="https://web.archive.org/web ...
# @media screen and (min-width:764px){.gTnfoj{width:200px;}}/*!sc*/
# @media screen and (min-width:1028px){.gTnfoj{width:300px;}}/*!sc*/
# .gaYPEQ{background-color:#FFFFFF;}/*!sc*/
# .btDPiJ{background-color:transparent;}/*!sc*/
# @media screen and (min-width:320px){.btDPiJ{width:29px;height:29px;}}/*!sc*/
# @media screen and (min-width:764px){.btDPiJ{width:58px;height:58px;}}/*!sc*/
# @media screen and (min-width:320px){.hjyNCj{margin-left:10px;}}/*!sc*/
# @media screen and (min-width:764px){.hjyNCj{margin-left:20px;}}/*!sc*/
# @media screen and (min-width:764px){.kMopVb{display:none;}}/*!sc*/
# .iGHGxS{z-index:2;position:relative;}/*!sc*/
# .jewEVl{width:24px;height:24px;}/*!sc*/
# .flhuNP{margin-left:5px;margin-right:5px;}/*!sc*/
# .eKtpfA{width:24px;height:24px;background-color:transparent;}/*!sc*/
# .gucGPE{position:relative;}/*!sc*/
# @media screen and (min-width:320px){.gucGPE{display:none;}}/*!sc*/
# @media screen and (min-width:764px){.gucGPE{display:initial;}}/*!sc*/
# .fbmXps{margin-left:10px;}/*!sc*/
# .bFNVvf{margin-bottom:20px;}/*!sc*/
# .gFlITA{margin-top:10px;}/*!sc*/
# @media screen and (min-width:320px){.fYkcJU{padding-top:0;}}/*!sc*/
# @media screen and (min-width:764px){.fYkcJU{padding-top:0;}}/*!sc*/
# @media screen and (min-width:320px){.fQMHMH{display:none;}}/*!sc*/
# @media screen and (min-width:764px){.fQMHMH{display:inline;}}/*!sc*/
# .bxvvVY{margin-bottom:5px;}/*!sc*/
# @media screen and (min-width:320px){.bEpoyR{padding-top:20px;}}/*!sc*/
# @media screen and (min-width:764px){.bEpoyR{padding-top:30px;}}/*!sc*/
# .gtdQxN{margin-right:auto;}/*!sc*/
# @media screen and (min-width:320px){.kuwTOb{padding-top:30px;}}/*!sc*/
# @media screen and (min-width:764px){.kuwTOb{padding-top:0;}}/*!sc*/
# .iarqEm{padding-top:120px;}/*!sc*/
# @media screen and (min-width:320px){.iarqEm{margin-bottom:20px;}}/*!sc*/
# @media screen and (min-width:764px){.iarqEm{margin-bottom:10px;}}/*!sc*/
# .iQrPtc{width:16px;height:16px;background-color:transparent;}/*!sc*/
# @media screen and (min-width:320px){.xDgju{padding-top:20px;padding-bottom:30px;}}/*!sc*/
# @media screen and (min-width:764px){.xDgju{padding-top:10px;padding-bottom:20px;}}/*!sc*/
# .dmwNVS{margin-right:auto;padding-bottom:10px;}/*!sc*/
# .kXpspU{margin-bottom:10px;}/*!sc*/
# .hccMOY{padding-top:20px;}/*!sc*/
# .laBJqN{padding-bottom:30px;}/*!sc*/
# data-styled.g1[id="Box-omzyfs-0"]{content:"klATQN,gTnfoj,gaYPEQ,btDPiJ,hjyNCj,kMopVb,iGHGxS,jewEVl,flhuNP,eKtpfA,jyLLA,gucGPE,fbmXps,bFNVvf,gFlITA,fYkcJU,fQMHMH,bxvvVY,bEpoyR,gtdQxN,kuwTOb,iarqEm,iQrPtc,xDgju,dmwNVS,kXpspU,hccMOY,laBJqN,"}/*!sc*/
# .fQoUUL{padding-top:5px;padding-bottom:5px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# @media screen and (min-width:320px){.fQoUUL{display:none;}}/*!sc*/
# @media screen and (min-width:764px){.fQoUUL{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}}/*!sc*/
# .ebaaK{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .fNoyQA{margin-right:20px;width:50px;height:50px;color:#F2F2F2;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .hreRbu{margin-left:30px;width:24px;height:24px;color:#F2F2F2;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .jewavn{width:24px;height:24px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .hKbHMj{width:8px;height:8px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .hEGLBC{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .eBZaEJ{padding-left:20px;height:100%;border-left-width:1px;border-left-style:solid;border-left-color:#333333;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# .isQWeh{padding-top:20px;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# .dhITPq{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# .jltgzU{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;}/*!sc*/
# @media screen and (min-width:320px){.jltgzU{width:29px;height:29px;}}/*!sc*/
# @media screen and (min-width:764px){.jltgzU{width:58px;height:58px;}}/*!sc*/
# .eXsMFc{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# @media screen and (min-width:320px){.eXsMFc{overflow:hidden;}}/*!sc*/
# @media screen and (min-width:764px){.eXsMFc{overflow:visible;}}/*!sc*/
# @media screen and (min-width:764px){.eXsMFc{-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}}/*!sc*/
# .husBkq{height:60px;background-color:#000000;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .dQKRnM{width:24px;height:24px;color:#F2F2F2;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .mXLUs{padding-left:10px;padding-right:10px;padding-top:10px;padding-bottom:10px;overflow-x:hidden;width:100%;background-color:#000000;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .gXVHzG{margin-right:10px;width:24px;height:24px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;}/*!sc*/
# .fISabH{padding-top:20px;padding-bottom:20px;margin-right:30px;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .inXEzg{padding-right:10px;width:24px;height:24px;color:#FF4848;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .cshLAo{padding-top:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# .htYgja{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# @media screen and (min-width:320px){.htYgja{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}}/*!sc*/
# @media screen and (min-width:764px){.htYgja{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}}/*!sc*/
# .jVLhoy{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# .lefkBu{padding-bottom:20px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .PDlOW{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# .jYikCb{height:30px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .hoMiiH{margin-right:5px;width:24px;height:24px;color:#FF4848;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .dqkjhR{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;}/*!sc*/
# .fCFvgO{margin-top:10px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# .fOOuYI{margin-right:10px;height:30px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .faxXyr{margin-right:5px;width:24px;height:24px;color:#666666;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .ckhhzu{padding-top:30px;padding-bottom:60px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;}/*!sc*/
# .jCrfZq{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}/*!sc*/
# .fsoYzJ{width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# @media screen and (min-width:320px){.fsoYzJ{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;}}/*!sc*/
# @media screen and (min-width:764px){.fsoYzJ{-webkit-flex-direction:row-reverse;-ms-flex-direction:row-reverse;flex-direction:row-reverse;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}}/*!sc*/
# .iKjPuv{width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# @media screen and (min-width:320px){.iKjPuv{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:flex-end;-webkit-box-align:flex-end;-ms-flex-align:flex-end;align-items:flex-end;}}/*!sc*/
# @media screen and (min-width:764px){.iKjPuv{-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}}/*!sc*/
# .kUSrsQ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# @media screen and (min-width:320px){.kUSrsQ{height:auto;}}/*!sc*/
# @media screen and (min-width:764px){.kUSrsQ{height:100%;}}/*!sc*/
# @media screen and (min-width:320px){.kUSrsQ{-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;}}/*!sc*/
# @media screen and (min-width:764px){.kUSrsQ{-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}}/*!sc*/
# .Llcor{padding-top:20px;padding-bottom:20px;border-top:1px solid;border-color:#333333;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}/*!sc*/
# .gdYSgl{padding-top:20px;width:56px;height:56px;color:#F2F2F2;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# @media screen and (min-width:320px){.gdYSgl{padding-bottom:20px;}}/*!sc*/
# @media screen and (min-width:764px){.gdYSgl{padding-bottom:30px;}}/*!sc*/
# .brhDbQ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;}/*!sc*/
# @media screen and (min-width:320px){.brhDbQ{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}}/*!sc*/
# @media screen and (min-width:764px){.brhDbQ{-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}}/*!sc*/
# .uQYjG{margin-top:20px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:start;-webkit-box-align:start;-ms-flex-align:start;align-items:start;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# .dsBcmb{margin-right:30px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .gvRTfq{margin-right:10px;width:16px;height:16px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;}/*!sc*/
# .kezmvR{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}/*!sc*/
# @media screen and (min-width:764px){.kezmvR{-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;}}/*!sc*/
# .ecrMfB{width:24px;height:24px;color:#F2F2F2;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# @media screen and (min-width:320px){.ecrMfB{padding-right:30px;}}/*!sc*/
# @media screen and (min-width:764px){.ecrMfB{padding-right:20px;}}/*!sc*/
# .glrSCJ{width:24px;height:24px;color:#F2F2F2;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# @media screen and (min-width:320px){.glrSCJ{padding-right:30px;}}/*!sc*/
# @media screen and (min-width:764px){.glrSCJ{padding-left:20px;padding-right:20px;}}/*!sc*/
# .jnWWgS{width:24px;height:24px;color:#F2F2F2;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# @media screen and (min-width:320px){.jnWWgS{padding-left:0;}}/*!sc*/
# @media screen and (min-width:764px){.jnWWgS{padding-left:20px;}}/*!sc*/
# .cJaEKE{width:40px;height:40px;color:#FFFFFF;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .fuulBO{padding-top:20px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# .hIFNdB{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# .hMKqpG{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# .hbijDA{height:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .enhtVU{width:8px;height:8px;color:#151515;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .hvdRrR{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# .gWWzeG{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}/*!sc*/
# .bfwefT{padding-bottom:30px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .gEnCAT{margin-right:10px;width:24px;height:24px;color:#FF4848;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g2[id="sc-AxjAm"]{content:"fQoUUL,ebaaK,fNoyQA,hreRbu,jewavn,hKbHMj,hEGLBC,eBZaEJ,isQWeh,dhITPq,jltgzU,eXsMFc,husBkq,dQKRnM,mXLUs,gXVHzG,fISabH,inXEzg,cshLAo,htYgja,jVLhoy,lefkBu,PDlOW,jYikCb,hoMiiH,dqkjhR,fCFvgO,fOOuYI,faxXyr,ckhhzu,jCrfZq,fsoYzJ,iKjPuv,kUSrsQ,Llcor,gdYSgl,brhDbQ,uQYjG,dsBcmb,gvRTfq,kezmvR,ecrMfB,glrSCJ,jnWWgS,cJaEKE,fuulBO,hIFNdB,hMKqpG,hbijDA,enhtVU,hvdRrR,gWWzeG,bfwefT,gEnCAT,"}/*!sc*/
# .jClxZp{display:grid;grid-gap:20px;grid-auto-flow:column;grid-template-columns:repeat( 10,71% );width:100%;}/*!sc*/
# @media (min-width:764px){.jClxZp{display:grid;grid-auto-flow:column;grid-template-columns:repeat( 4, 1fr );width:100%;}.jClxZp > :nth-child(n + 5 ){display:none;}}/*!sc*/
# @media (min-width:1028px){.jClxZp{display:grid;grid-template-columns:repeat(4,1fr);grid-auto-flow:column;}}/*!sc*/
# .fHKIhJ{display:grid;grid-gap:20px;grid-auto-flow:row;grid-template-columns:repeat( 1,1fr );width:100%;}/*!sc*/
# @media (min-width:764px){.fHKIhJ{display:grid;grid-auto-flow:column;grid-template-columns:repeat( 2, 2fr );width:auto;}.fHKIhJ > :nth-child(n + 13 ){display:none;}}/*!sc*/
# @media (min-width:1028px){.fHKIhJ{display:grid;grid-template-columns:repeat(12,1fr);grid-auto-flow:column;}}/*!sc*/
# .fuNsvk{display:grid;grid-gap:20px;grid-auto-flow:column;grid-template-columns:repeat( 1,1fr );width:100%;margin-bottom:10px;}/*!sc*/
# @media (min-width:764px){.fuNsvk{display:grid;grid-auto-flow:column;grid-template-columns:repeat( 8, 1fr );width:auto;}.fuNsvk > :nth-child(n + 9 ){display:none;}}/*!sc*/
# @media (min-width:1028px){.fuNsvk{display:grid;grid-template-columns:repeat(8,1fr);grid-auto-flow:column;}}/*!sc*/
# .bZHrRV{display:grid;grid-gap:20px;grid-auto-flow:column;grid-template-columns:repeat( 6,71% );width:100%;grid-row-gap:0;}/*!sc*/
# @media (min-width:764px){.bZHrRV{display:grid;grid-auto-flow:row;grid-template-columns:repeat( 3, 1fr );width:100%;}.bZHrRV > :nth-child(n + 4 ){display:block;}}/*!sc*/
# @media (min-width:1028px){.bZHrRV{display:grid;grid-template-columns:repeat(3,1fr);grid-auto-flow:row;}}/*!sc*/
# .eZwAVc{display:grid;grid-gap:20px;grid-auto-flow:row;grid-template-columns:repeat( 1,1fr );width:100%;}/*!sc*/
# @media (min-width:764px){.eZwAVc{display:grid;grid-auto-flow:row;grid-template-columns:repeat( 2, 1fr );width:auto;}.eZwAVc > :nth-child(n + 3 ){display:block;}}/*!sc*/
# @media (min-width:1028px){.eZwAVc{display:grid;grid-template-columns:repeat(2,1fr);grid-auto-flow:column;}}/*!sc*/
# @media screen and (min-width:320px){.eZwAVc{grid-gap:10px;}}/*!sc*/
# @media screen and (min-width:764px){.eZwAVc{grid-gap:0;}}/*!sc*/
# data-styled.g3[id="Grid__GridStyled-sc-1l00ugd-0"]{content:"jClxZp,fHKIhJ,fuNsvk,bZHrRV,eZwAVc,"}/*!sc*/
# .gnwWng{display:list-item;grid-column:span undefined;}/*!sc*/
# @media (min-width:764px){.gnwWng{display:list-item;}}/*!sc*/
# @media (min-width:1028px){.gnwWng{display:list-item;}}/*!sc*/
# @media (min-width:764px){.gnwWng{grid-column:span undefined;}}/*!sc*/
# @media (min-width:1028px){.gnwWng{grid-column:span 7;}}/*!sc*/
# .jHShKh{display:list-item;grid-column:span undefined;}/*!sc*/
# @media (min-width:764px){.jHShKh{display:list-item;}}/*!sc*/
# @media (min-width:1028px){.jHShKh{display:list-item;}}/*!sc*/
# @media (min-width:764px){.jHShKh{grid-column:span 8;}}/*!sc*/
# @media (min-width:1028px){.jHShKh{grid-column:span 8;}}/*!sc*/
# .bvSosG{display:list-item;grid-column:span undefined;}/*!sc*/
# @media (min-width:764px){.bvSosG{display:list-item;}}/*!sc*/
# @media (min-width:1028px){.bvSosG{display:list-item;}}/*!sc*/
# @media (min-width:764px){.bvSosG{grid-column:span undefined;}}/*!sc*/
# @media (min-width:1028px){.bvSosG{grid-column:span 5;}}/*!sc*/
# .jgvRrJ{display:list-item;grid-column:span undefined;}/*!sc*/
# @media (min-width:764px){.jgvRrJ{display:list-item;}}/*!sc*/
# @media (min-width:1028px){.jgvRrJ{display:list-item;}}/*!sc*/
# @media (min-width:764px){.jgvRrJ{grid-column:span undefined;}}/*!sc*/
# @media (min-width:1028px){.jgvRrJ{grid-column:span undefined;}}/*!sc*/
# data-styled.g4[id="Column-sc-18hsrnn-0"]{content:"gnwWng,jHShKh,bvSosG,jgvRrJ,"}/*!sc*/
# .jBqnIi{display:grid;grid-template-columns:[full-start] 20px [main-start] calc(100% - (40px)) [main-end] 20px [full-end];}/*!sc*/
# @media (min-width:764px){.jBqnIi{grid-template-columns:[full-start] 1fr [main-start] 748px [main-end] 1fr [full-end];}}/*!sc*/
# @media (min-width:1028px){.jBqnIi{grid-template-columns:[full-start] 1fr [main-start] 988px [main-end] 1fr [full-end];}}/*!sc*/
# @media (min-width:1442px){.jBqnIi{grid-template-columns:[full-start] 1fr [main-start] 1180px [main-end] 1fr [full-end];}}/*!sc*/
# .jBqnIi > *{grid-column:main;}/*!sc*/
# data-styled.g6[id="Layout-sc-1j5bbdx-0"]{content:"jBqnIi,"}/*!sc*/
# .iNZQVz{color:#151515;font-weight:400;font-family:AlternateGothicPro,sans-serif;font-size:50px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:54px;}/*!sc*/
# @media (min-width:1028px){.iNZQVz{font-family:AlternateGothicPro,sans-serif;font-size:120px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:120px;}}/*!sc*/
# .ktVryU{color:#F2F2F2;padding-left:10px;font-weight:400;font-family:Helvetica;font-size:16px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:20px;}/*!sc*/
# @media (min-width:1028px){.ktVryU{font-family:Helvetica;font-size:16px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:20px;}}/*!sc*/
# .hhfigA{color:#F2F2F2;font-weight:400;font-family:RobotoMono,monospace;font-size:11px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:12px;}/*!sc*/
# @media (min-width:1028px){.hhfigA{font-family:RobotoMono,monospace;font-size:11px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:11px;}}/*!sc*/
# .iCPqUT{color:#FF4848;padding-right:5px;font-weight:400;font-family:AlternateGothicPro,sans-serif;font-size:36px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:36px;}/*!sc*/
# @media (min-width:1028px){.iCPqUT{font-family:AlternateGothicPro,sans-serif;font-size:50px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:50px;}}/*!sc*/
# .ejtJjV{text-transform:uppercase;color:#666666;font-weight:400;font-family:AlternateGothicPro,sans-serif;font-size:24px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:26px;}/*!sc*/
# @media (min-width:1028px){.ejtJjV{font-family:AlternateGothicPro,sans-serif;font-size:24px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:26px;}}/*!sc*/
# .dvCBwl{text-transform:uppercase;color:#FF4848;font-weight:400;font-family:AlternateGothicPro,sans-serif;font-size:30px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:30px;}/*!sc*/
# @media (min-width:1028px){.dvCBwl{font-family:AlternateGothicPro,sans-serif;font-size:36px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:36px;}}/*!sc*/
# .gSvLLX{color:#FF4848;padding-right:5px;font-weight:400;font-family:AlternateGothicPro,sans-serif;font-size:30px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:30px;}/*!sc*/
# @media (min-width:1028px){.gSvLLX{font-family:AlternateGothicPro,sans-serif;font-size:36px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:36px;}}/*!sc*/
# .dWOMtb{color:#F2F2F2;margin-top:10px;display:-webkit-box;-webkit-line-clamp:2;-webkit-box-orient:vertical;overflow:hidden;font-weight:400;font-family:Helvetica;font-size:16px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:20px;}/*!sc*/
# @media (min-width:1028px){.dWOMtb{font-family:Helvetica;font-size:16px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:20px;}}/*!sc*/
# .dtYoLc{color:#666666;font-weight:400;font-family:RobotoMono,monospace;font-size:11px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:12px;}/*!sc*/
# @media (min-width:1028px){.dtYoLc{font-family:RobotoMono,monospace;font-size:11px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:11px;}}/*!sc*/
# .dPhbWT{color:#666666;margin-right:20px;font-weight:400;font-family:AlternateGothicPro,sans-serif;font-size:30px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:30px;}/*!sc*/
# @media (min-width:1028px){.dPhbWT{font-family:AlternateGothicPro,sans-serif;font-size:36px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:36px;}}/*!sc*/
# .eEmOUn{color:#777777;padding-right:5px;font-weight:400;font-family:AlternateGothicPro,sans-serif;font-size:36px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:36px;}/*!sc*/
# @media (min-width:1028px){.eEmOUn{font-family:AlternateGothicPro,sans-serif;font-size:50px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:50px;}}/*!sc*/
# .iAvnsf{color:#666666;padding-bottom:10px;font-weight:400;font-family:RobotoMono,monospace;font-size:11px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:12px;}/*!sc*/
# @media (min-width:1028px){.iAvnsf{font-family:RobotoMono,monospace;font-size:11px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:11px;}}/*!sc*/
# .gavPXg{color:#777777;padding-left:10px;padding-right:5px;font-weight:400;font-family:AlternateGothicPro,sans-serif;font-size:36px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:36px;}/*!sc*/
# @media (min-width:1028px){.gavPXg{font-family:AlternateGothicPro,sans-serif;font-size:50px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:50px;}}/*!sc*/
# .gThKyY{color:#666666;margin-bottom:20px;font-weight:400;font-family:AlternateGothicPro,sans-serif;font-size:36px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:36px;}/*!sc*/
# @media (min-width:1028px){.gThKyY{font-family:AlternateGothicPro,sans-serif;font-size:50px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:50px;}}/*!sc*/
# .icfXUw{color:#666666;margin-right:10px;font-weight:400;font-family:Helvetica;font-size:13px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:20px;}/*!sc*/
# @media (min-width:1028px){.icfXUw{font-family:Helvetica;font-size:13px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:20px;}}/*!sc*/
# .UKLpo{color:#F2F2F2;padding-left:5px;padding-right:5px;font-weight:400;font-family:Helvetica;font-size:13px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:20px;}/*!sc*/
# @media (min-width:1028px){.UKLpo{font-family:Helvetica;font-size:13px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:20px;}}/*!sc*/
# .kfhhsg{color:#666666;padding-bottom:10px;font-weight:400;font-family:Helvetica;font-size:13px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:20px;}/*!sc*/
# @media (min-width:1028px){.kfhhsg{font-family:Helvetica;font-size:13px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:20px;}}/*!sc*/
# .gGBUhc{color:#DDDDDD;padding-left:10px;padding-right:5px;font-weight:400;font-family:AlternateGothicPro,sans-serif;font-size:50px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:54px;}/*!sc*/
# @media (min-width:1028px){.gGBUhc{font-family:AlternateGothicPro,sans-serif;font-size:120px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:120px;}}/*!sc*/
# .fSkQNv{color:#151515;font-weight:400;font-family:Helvetica;font-size:16px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:20px;font-weight:600;}/*!sc*/
# @media (min-width:1028px){.fSkQNv{font-family:Helvetica;font-size:16px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:20px;font-weight:600;}}/*!sc*/
# data-styled.g7[id="Text-sc-1t0gn2o-0"]{content:"iNZQVz,ktVryU,hhfigA,iCPqUT,ejtJjV,dvCBwl,gSvLLX,dWOMtb,dtYoLc,dPhbWT,eEmOUn,iAvnsf,gavPXg,gThKyY,icfXUw,UKLpo,kfhhsg,gGBUhc,fSkQNv,"}/*!sc*/
# .ZRbDn{cursor:pointer;border-radius:20px;border-style:solid;-webkit-tap-highlight-color:rgba(0,0,0,0);-webkit-tap-highlight-color:transparent;font-family:RobotoMono,monospace;font-size:11px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:12px;border-width:2px;padding-right:20px;padding-left:20px;height:40px;min-width:40px;position:relative;overflow:hidden;border-color:transparent;background-color:transparent;color:#F2F2F2;}/*!sc*/
# @media (min-width:1028px){.ZRbDn{font-family:RobotoMono,monospace;font-size:11px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:11px;}}/*!sc*/
# .ZRbDn:hover{border-color:transparent;background-color:transparent;color:#FF4848;}/*!sc*/
# .ZRbDn:disabled{border-color:transparent;background-color:transparent;color:#F2F2F2;opacity:0.4;cursor:auto;}/*!sc*/
# .bdUXJP{cursor:pointer;border-radius:20px;border-style:solid;-webkit-tap-highlight-color:rgba(0,0,0,0);-webkit-tap-highlight-color:transparent;font-family:RobotoMono,monospace;font-size:11px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:12px;border-width:2px;padding-left:20px;padding-right:20px;height:40px;min-width:40px;position:relative;overflow:hidden;border-color:#333333;background-color:transparent;color:#F2F2F2;}/*!sc*/
# @media (min-width:1028px){.bdUXJP{font-family:RobotoMono,monospace;font-size:11px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:11px;}}/*!sc*/
# .bdUXJP:hover{border-color:#333333;background-color:#333333;color:#F2F2F2;}/*!sc*/
# .bdUXJP:disabled{border-color:#333333;background-color:transparent;color:#F2F2F2;opacity:0.4;cursor:auto;}/*!sc*/
# .dXIODd{cursor:pointer;border-radius:20px;border-style:solid;-webkit-tap-highlight-color:rgba(0,0,0,0);-webkit-tap-highlight-color:transparent;font-family:RobotoMono,monospace;font-size:11px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:12px;border-width:2px;padding-top:10px;padding-left:0;padding-right:10px;height:40px;min-width:40px;position:relative;overflow:hidden;border-color:transparent;background-color:transparent;color:#151515;}/*!sc*/
# @media (min-width:1028px){.dXIODd{font-family:RobotoMono,monospace;font-size:11px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:11px;}}/*!sc*/
# .dXIODd:hover{border-color:transparent;background-color:transparent;color:#FF4848;}/*!sc*/
# .dXIODd:disabled{border-color:transparent;background-color:transparent;color:#151515;opacity:0.4;cursor:auto;}/*!sc*/
# data-styled.g11[id="Button__ButtonStyled-sc-1a57dzu-0"]{content:"ZRbDn,bdUXJP,dXIODd,"}/*!sc*/
# .gDVXtE{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;position:relative;}/*!sc*/
# data-styled.g13[id="Button__StyledAlignment-sc-1a57dzu-2"]{content:"gDVXtE,"}/*!sc*/
# .cDIIME{cursor:pointer;border-radius:20px;border-style:solid;-webkit-tap-highlight-color:rgba(0,0,0,0);-webkit-tap-highlight-color:transparent;font-family:RobotoMono,monospace;font-size:11px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:12px;border-width:2px;padding-left:20px;padding-right:20px;height:40px;min-width:40px;border-color:#FF4848;background-color:transparent;color:#F2F2F2;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-text-decoration:none;text-decoration:none;box-sizing:border-box;}/*!sc*/
# @media (min-width:1028px){.cDIIME{font-family:RobotoMono,monospace;font-size:11px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:11px;}}/*!sc*/
# .cDIIME:hover{border-color:#FF4848;background-color:#FF4848;color:#F2F2F2;}/*!sc*/
# .cDIIME:disabled{border-color:#FF4848;background-color:transparent;color:#F2F2F2;opacity:0.4;cursor:auto;}/*!sc*/
# .cDIIME variant{border-color:#333333;background-color:transparent;color:#F2F2F2;}/*!sc*/
# .cDIIME variant:hover{border-color:#333333;background-color:#333333;color:#F2F2F2;}/*!sc*/
# .cDIIME variant:disabled{border-color:#333333;background-color:transparent;color:#F2F2F2;opacity:0.4;cursor:auto;}/*!sc*/
# data-styled.g14[id="LinkButton__LinkButtonStyled-gtbvrf-0"]{content:"cDIIME,"}/*!sc*/
# .gCXHdZ{background-color:#FF4848;color:#F2F2F2;font-weight:400;font-family:RobotoMono,monospace;font-size:11px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:12px;padding:4px 5px 5px 6px;color:#F2F2F2;}/*!sc*/
# @media (min-width:1028px){.gCXHdZ{font-family:RobotoMono,monospace;font-size:11px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:12px;}}/*!sc*/
# data-styled.g15[id="Tag__TagStyled-sc-1ss46so-0"]{content:"gCXHdZ,"}/*!sc*/
# .klshtO{width:100%;border:0;border-bottom-color:#333333;border-bottom-style:solid;border-bottom-width:1px;margin-bottom:10px;}/*!sc*/
# .kwUhJN{width:100%;border:0;border-bottom-color:#333333;border-bottom-style:solid;border-bottom-width:1px;border-color:#FF4848;margin-bottom:0;}/*!sc*/
# .gUsThe{width:100%;border:0;border-bottom-color:#333333;border-bottom-style:solid;border-bottom-width:1px;}/*!sc*/
# data-styled.g20[id="Divider__HorizontalDivider-sc-1qsmuc-0"]{content:"klshtO,kwUhJN,gUsThe,"}/*!sc*/
# .ggOjRx{border-right-width:1px;height:100%;width:0px;border-right-color:#333333;border-right-style:solid;border-right-width:1px;}/*!sc*/
# data-styled.g21[id="Divider__VerticalDivider-sc-1qsmuc-1"]{content:"ggOjRx,"}/*!sc*/
# .fpdMIH{padding-bottom:141.42%;position:relative;height:0;display:block;width:100%;}/*!sc*/
# .fpdMIH > *{position:absolute;top:0;left:0;width:100%;height:100%;display:block;}/*!sc*/
# data-styled.g28[id="Lazy__Wrapper-sc-1kakvxs-0"]{content:"fpdMIH,"}/*!sc*/
# .bTFSZj{color:#F2F2F2;font-weight:400;font-family:Helvetica;font-size:16px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:20px;cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# @media (min-width:1028px){.bTFSZj{font-family:Helvetica;font-size:16px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:20px;}}/*!sc*/
# .bTFSZj:hover{color:#FF4848;}/*!sc*/
# .fgyQjb{color:#151515;font-weight:400;font-family:AlternateGothicPro,sans-serif;font-size:36px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:36px;cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# @media (min-width:1028px){.fgyQjb{font-family:AlternateGothicPro,sans-serif;font-size:50px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:50px;}}/*!sc*/
# .fgyQjb:hover{color:#FF4848;}/*!sc*/
# .JkRpv{color:#666666;font-weight:400;font-family:AlternateGothicPro,sans-serif;font-size:36px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:36px;cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# @media (min-width:1028px){.JkRpv{font-family:AlternateGothicPro,sans-serif;font-size:50px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:50px;}}/*!sc*/
# .JkRpv:hover{color:#FF4848;}/*!sc*/
# .clcVFR{color:#F2F2F2;font-weight:600;font-family:Helvetica;font-size:13px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:20px;cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# @media (min-width:1028px){.clcVFR{font-family:Helvetica;font-size:13px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:20px;}}/*!sc*/
# .clcVFR:hover{color:#FF4848;}/*!sc*/
# .fAmOyf{color:#F2F2F2;font-weight:400;font-family:AlternateGothicPro,sans-serif;font-size:30px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:30px;cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# @media (min-width:1028px){.fAmOyf{font-family:AlternateGothicPro,sans-serif;font-size:36px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:36px;}}/*!sc*/
# .fAmOyf:hover{color:#FF4848;}/*!sc*/
# .knBJCg{color:#F2F2F2;font-weight:400;font-family:RobotoMono,monospace;font-size:11px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:12px;cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# @media (min-width:1028px){.knBJCg{font-family:RobotoMono,monospace;font-size:11px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:11px;}}/*!sc*/
# .knBJCg:hover{color:#FF4848;}/*!sc*/
# .iHZuSI{color:#666666;font-weight:400;font-family:RobotoMono,monospace;font-size:11px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:12px;cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# @media (min-width:1028px){.iHZuSI{font-family:RobotoMono,monospace;font-size:11px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:11px;}}/*!sc*/
# .iHZuSI:hover{color:#FF4848;}/*!sc*/
# .eIXPIq{color:#F2F2F2;display:block;font-weight:400;font-family:AlternateGothicPro,sans-serif;font-size:36px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:36px;cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# @media screen and (min-width:320px){.eIXPIq{padding-bottom:30px;}}/*!sc*/
# @media screen and (min-width:764px){.eIXPIq{padding-bottom:0;}}/*!sc*/
# @media (min-width:1028px){.eIXPIq{font-family:AlternateGothicPro,sans-serif;font-size:50px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:50px;}}/*!sc*/
# .eIXPIq:hover{color:#FF4848;}/*!sc*/
# .kiMBxl{color:#F2F2F2;font-weight:600;font-family:Helvetica;font-size:16px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:20px;cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# @media (min-width:1028px){.kiMBxl{font-family:Helvetica;font-size:16px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:20px;}}/*!sc*/
# .kiMBxl:hover{color:#FF4848;}/*!sc*/
# .jIvqvn{color:#F2F2F2;padding-right:10px;font-weight:400;font-family:AlternateGothicPro,sans-serif;font-size:36px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:36px;cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# @media (min-width:1028px){.jIvqvn{font-family:AlternateGothicPro,sans-serif;font-size:50px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:50px;}}/*!sc*/
# .jIvqvn:hover{color:#FF4848;}/*!sc*/
# .YXHKX{color:#F2F2F2;margin-bottom:10px;font-weight:400;font-family:AlternateGothicPro,sans-serif;font-size:36px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:36px;cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# @media (min-width:1028px){.YXHKX{font-family:AlternateGothicPro,sans-serif;font-size:50px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:50px;}}/*!sc*/
# .YXHKX:hover{color:#FF4848;}/*!sc*/
# .chAlCf{color:#F2F2F2;font-weight:400;font-family:AlternateGothicPro,sans-serif;font-size:36px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:36px;cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# @media (min-width:1028px){.chAlCf{font-family:AlternateGothicPro,sans-serif;font-size:50px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:50px;}}/*!sc*/
# .chAlCf:hover{color:#FF4848;}/*!sc*/
# .flrWGL{color:#F2F2F2;font-weight:400;font-family:Helvetica;font-size:13px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:20px;cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# @media (min-width:1028px){.flrWGL{font-family:Helvetica;font-size:13px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:20px;}}/*!sc*/
# .flrWGL:hover{color:#FF4848;}/*!sc*/
# .dxAeeL{color:#151515;font-weight:400;font-family:Helvetica;font-size:16px;-webkit-letter-spacing:0px;-moz-letter-spacing:0px;-ms-letter-spacing:0px;letter-spacing:0px;line-height:20px;font-weight:600;cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# ...
#         .sticky-header {
#           top: 60px !important;
#         }
#       </style><nav aria-label="Secondary" class="SubNav___StyledNav-y61b6j-0 mtepk" data-tracking-id="reviews-sub-nav"><div class="Layout-sc-1j5bbdx-0 SubNav___StyledLayout-y61b6j-1 jAmJHF"><div class="Box-omzyfs-0 sc-AxjAm eXsMFc" overflow="[object Object]"><div class="Box-omzyfs-0 kMopVb" display="[object Object]"><div id="filter-list-small"><div class="Box-omzyfs-0 iGHGxS"><div class="Box-omzyfs-0 sc-AxjAm husBkq" height="60"><button aria-disabled="false" class="StyledButton-sc-192eei6-0 Button__ButtonStyled-sc-1a57dzu-0 ZRbDn" data-button-tracking-id="toggle-show-filter-list-open" height="40" role="button"><div class="Box-omzyfs-0 sc-AxjAm Button__StyledAlignment-sc-1a57dzu-2 gDVXtE"><div class="Box-omzyfs-0 sc-AxjAm ebaaK"><div class="Box-omzyfs-0 jewEVl" height="24" width="24"><div class="Box-omzyfs-0 sc-AxjAm dQKRnM" color="primary" height="24" width="24"><svg aria-label="Filter" height="100%" viewbox="0 0 24 24" width="100%"><g fill="#FFF" fill-rule="evenodd"><path d="M0 0h24v24H0z" fill="none"></path><path d="M11 16c1.302 0 2.401.839 2.816 2H21a1 1 0 110 2h-7.184A2.997 2.997 0 0111 22a2.995 2.995 0 01-2.815-2H3a1 1 0 110-2h5.184A2.997 2.997 0 0111 16zm0 2a1.001 1.001 0 000 2 1.001 1.001 0 000-2zm4-9c1.302 0 2.401.839 2.816 2H21a1 1 0 110 2h-3.184A2.997 2.997 0 0115 15a2.995 2.995 0 01-2.815-2H3a1 1 0 110-2h9.184A2.997 2.997 0 0115 9zm0 2a1.001 1.001 0 000 2 1.001 1.001 0 000-2zM8 2c1.302 0 2.401.839 2.816 2H21a1 1 0 110 2H10.816A2.997 2.997 0 018 8a2.995 2.995 0 01-2.815-2H3a1 1 0 110-2h2.184A2.997 2.997 0 018 2zm0 2a1.001 1.001 0 000 2 1.001 1.001 0 000-2z" fill="currentColor"></path></g></svg></div></div><div class="FilterListSmall__Animation-rdzbkm-0 gioaBR" style="overflow:hidden;width:auto;opacity:1"><span class="Text-sc-1t0gn2o-0 ktVryU" color="primary" font-weight="normal">Filter</span></div></div></div></button><div class="FilterListSmall__Animation-rdzbkm-0 fZjOeA" style="width:0vw;opacity:0;display:none"><div class="Box-omzyfs-0 sc-AxjAm mXLUs" width="100%"><div class="Box-omzyfs-0 flhuNP"><button aria-disabled="false" class="StyledButton-sc-192eei6-0 Button__ButtonStyled-sc-1a57dzu-0 bdUXJP" data-button-tracking-id="open-date-filter-modal" height="40"><div class="Box-omzyfs-0 sc-AxjAm Button__StyledAlignment-sc-1a57dzu-2 gDVXtE">Sat, 30 Mar 2019</div></button></div><div class="Box-omzyfs-0 flhuNP"><button aria-disabled="false" class="StyledButton-sc-192eei6-0 Button__ButtonStyled-sc-1a57dzu-0 bdUXJP" data-button-tracking-id="open-location-filter-modal" height="40"><div class="Box-omzyfs-0 sc-AxjAm Button__StyledAlignment-sc-1a57dzu-2 gDVXtE"><div class="Box-omzyfs-0 sc-AxjAm gXVHzG" height="24" width="24"><div class="Box-omzyfs-0 eKtpfA" height="24" width="24"></div></div><span class="Text-sc-1t0gn2o-0 hhfigA" color="primary" font-weight="normal">New York</span></div></button></div></div></div></div><div class="Box-omzyfs-0 Triangle__TriangleBox-sc-9xpz08-0 dSkOqL" height="60" width="60"></div><div class="Box-omzyfs-0 Triangle__TriangleBorder-sc-9xpz08-1 fPwLz" height="60" width="60"></div></div></div></div><div class="Box-omzyfs-0 sc-AxjAm SubNav___StyledAlignment-y61b6j-2 hxNhEq" overflow="[object Object]"><div class="Box-omzyfs-0 jyLLA"><a class="Link__AnchorWrapper-k7o46r-1 cRvOHm SubNavLink___StyledLink-ld7eyt-0 dOnEjD" color="primary" data-tracking-id="/guide/us/newyork" font-weight="bold" href="/web/20210326225933/https://ra.co/guide/us/newyork" rel="" role="tab" target=""><span class="Text-sc-1t0gn2o-0 Link__StyledLink-k7o46r-0 clcVFR SubNavLink___StyledLink-ld7eyt-0 dOnEjD" color="primary" data-tracking-id="/guide/us/newyork" font-weight="bold" href="/guide/us/newyork" rel="" role="tab" target=""><div class="Box-omzyfs-0 sc-AxjAm fISabH">Overview</div></span></a></div><div class="Box-omzyfs-0 jyLLA"><a class="Link__AnchorWrapper-k7o46r-1 cRvOHm SubNavLink___StyledLink-ld7eyt-0 dOnEjD" color="primary" data-tracking-id="/events/us/newyork" font-weight="bold" href="/web/20210326225933/https://ra.co/ev ...
# // prettier-ignore
# if (Intl.RelativeTimeFormat && typeof Intl.RelativeTimeFormat.__addLocaleData === 'function') {
#   Intl.RelativeTimeFormat.__addLocaleData({"data":{"nu":["latn"],"year":{"0":"this year","1":"next year","future":{"one":"in {0} year","other":"in {0} years"},"past":{"one":"{0} year ago","other":"{0} years ago"},"-1":"last year"},"year-short":{"0":"this yr.","1":"next yr.","future":{"one":"in {0} yr.","other":"in {0} yr."},"past":{"one":"{0} yr. ago","other":"{0} yr. ago"},"-1":"last yr."},"year-narrow":{"0":"this yr.","1":"next yr.","future":{"one":"in {0} yr.","other":"in {0} yr."},"past":{"one":"{0} yr. ago","other":"{0} yr. ago"},"-1":"last yr."},"quarter":{"0":"this quarter","1":"next quarter","future":{"one":"in {0} quarter","other":"in {0} quarters"},"past":{"one":"{0} quarter ago","other":"{0} quarters ago"},"-1":"last quarter"},"quarter-short":{"0":"this qtr.","1":"next qtr.","future":{"one":"in {0} qtr.","other":"in {0} qtrs."},"past":{"one":"{0} qtr. ago","other":"{0} qtrs. ago"},"-1":"last qtr."},"quarter-narrow":{"0":"this qtr.","1":"next qtr.","future":{"one":"in {0} qtr.","other":"in {0} qtrs."},"past":{"one":"{0} qtr. ago","other":"{0} qtrs. ago"},"-1":"last qtr."},"month":{"0":"this month","1":"next month","future":{"one":"in {0} month","other":"in {0} months"},"past":{"one":"{0} month ago","other":"{0} months ago"},"-1":"last month"},"month-short":{"0":"this mo.","1":"next mo.","future":{"one":"in {0} mo.","other":"in {0} mo."},"past":{"one":"{0} mo. ago","other":"{0} mo. ago"},"-1":"last mo."},"month-narrow":{"0":"this mo.","1":"next mo.","future":{"one":"in {0} mo.","other":"in {0} mo."},"past":{"one":"{0} mo. ago","other":"{0} mo. ago"},"-1":"last mo."},"week":{"0":"this week","1":"next week","future":{"one":"in {0} week","other":"in {0} weeks"},"past":{"one":"{0} week ago","other":"{0} weeks ago"},"-1":"last week"},"week-short":{"0":"this wk.","1":"next wk.","future":{"one":"in {0} wk.","other":"in {0} wk."},"past":{"one":"{0} wk. ago","other":"{0} wk. ago"},"-1":"last wk."},"week-narrow":{"0":"this wk.","1":"next wk.","future":{"one":"in {0} wk.","other":"in {0} wk."},"past":{"one":"{0} wk. ago","other":"{0} wk. ago"},"-1":"last wk."},"day":{"0":"today","1":"tomorrow","future":{"one":"in {0} day","other":"in {0} days"},"past":{"one":"{0} day ago","other":"{0} days ago"},"-1":"yesterday"},"day-short":{"0":"today","1":"tomorrow","future":{"one":"in {0} day","other":"in {0} days"},"past":{"one":"{0} day ago","other":"{0} days ago"},"-1":"yesterday"},"day-narrow":{"0":"today","1":"tomorrow","future":{"one":"in {0} day","other":"in {0} days"},"past":{"one":"{0} day ago","other":"{0} days ago"},"-1":"yesterday"},"hour":{"0":"this hour","future":{"one":"in {0} hour","other":"in {0} hours"},"past":{"one":"{0} hour ago","other":"{0} hours ago"}},"hour-short":{"0":"this hour","future":{"one":"in {0} hr.","other":"in {0} hr."},"past":{"one":"{0} hr. ago","other":"{0} hr. ago"}},"hour-narrow":{"0":"this hour","future":{"one":"in {0} hr.","other":"in {0} hr."},"past":{"one":"{0} hr. ago","other":"{0} hr. ago"}},"minute":{"0":"this minute","future":{"one":"in {0} minute","other":"in {0} minutes"},"past":{"one":"{0} minute ago","other":"{0} minutes ago"}},"minute-short":{"0":"this minute","future":{"one":"in {0} min.","other":"in {0} min."},"past":{"one":"{0} min. ago","other":"{0} min. ago"}},"minute-narrow":{"0":"this minute","future":{"one":"in {0} min.","other":"in {0} min."},"past":{"one":"{0} min. ago","other":"{0} min. ago"}},"second":{"0":"now","future":{"one":"in {0} second","other":"in {0} seconds"},"past":{"one":"{0} second ago","other":"{0} seconds ago"}},"second-short":{"0":"now","future":{"one":"in {0} sec.","other":"in {0} sec."},"past":{"one":"{0} sec. ago","other":"{0} sec. ago"}},"second-narrow":{"0":"now","future":{"one":"in {0} sec.","other":"in {0} sec."},"past":{"one":"{0} sec. ago","other":"{0} sec. ago"}}},"locale":"en"}
# )
# }</script><script id="__NEXT_DATA__" type="application/json">{"props":{"pageProps":{},"locale":"en","messages":{"Errors.NotFoundWithEntityType":"{entityType} not found","Music.ArchiveTitle":"{genre} in {date}","Magazine.Genre":"{genreCount, plural, one {Genre} other {Genres}}","Magazine.Label":"{labelCount, plural, one {Label} other {Labels}}","Errors.RequiredWithPath":"{path} is required","Events.Promoter":"{promoterCount, plural, one {Promoter} other {Promoters}}","Magazine.TypeNews":"{type} News","Events.MinimumAgePolicy":"{venueName} is an over {minimumAge} venue","Dict.PrivacyAndTerms":"\u003cprivacy\u003ePrivacy\u003c/privacy\u003e \u0026 \u003cterms\u003eTerms\u003c/terms\u003e","Dict.About":"About","Events.AboutRegion":"About {region}","Dict.AboutRaTickets":"About RA Tickets","Events.AboutResale":"About resale","Auth.AboutYou":"About you","Dict.AccountSettings":"Account settings","Pro.AddNewArtist":"Add new artist","Pro.AddNewLabel":"Add new label","Pro.AddNewPromoter":"Add new promoter","Events.AdditionalInfo":"Additional info","Auth.Address":"Address","Events.Address":"Address","Dict.Advertise":"Advertise","Dict.Advertising":"Advertising","Dict.AdvertisingFormats":"Advertising Formats","Dict.AdvertisingTerms":"Advertising Terms","Dict.Age":"Age","Music.Albums":"Albums","Dict.Aliases":"Aliases","Dict.All":"All","Events.All":"All","Magazine.All":"All","Events.AllClubs":"All Clubs","Magazine.AllFilms":"All films","Music.AllGenres":"All genres","Events.AllPromoters":"All Promoters","Dict.AllRegions":"All regions","Dict.AllRightsReserved":"All rights reserved","Auth.AlreadyHaveAnAccount":"Already have an account?","Dict.AlsoAvailableInJapanese":"Also available in Japanese 日本版","Errors.UserAlreadyWithEmailAddress":"An account with this email address already exists","Dict.Archive":"Archive","Events.ArchiveOfEvents":"Archive of events","Events.AreYouAPromoter":"Are you a promoter?","Dict.Area":"Area","Pro.Artist":"Artist","Music.Artists":"Artists","Events.Attending":"Attending","Dict.Back":"Back","Errors.BadRequest":"Bad request","Dict.Based":"Based","Dict.Basic":"Basic","ShopFaq.Intro":"Below you will find answers to the most common questions asked by RA\n    Ticket customers","Dict.Biography":"Biography","Auth.Birthday":"Birthday","Dict.Blog":"Blog","Events.bookingInformation":"Booking information","Dict.Born":"Born","Events.BuyTickets":"Buy tickets","ShopFaq.CanIDisplayMyTicketOnMyPhoneQuestion":"Can I display my ticket on my phone?","ShopFaq.CanIgetARefundForTicketsIHaveBoughtQuestion":"Can I get a refund for tickets I have bought?","Events.Capacity":"Capacity","Magazine.Category":"Category","Events.CheckBackToPurchaseTicketsAsTheyBecomeAvailable":"Check back to purchase tickets as they become available.","Dict.Chinese":"Chinese","Auth.City":"City","Dict.Closed":"Closed","Events.Club":"Club","Events.ClubNews":"Club News","Events.Clubs":"Clubs","Events.clubsMostPlayed":"Clubs most played","Dict.CommunityConnections":"Community Connections","Dict.CommunityProjects":"Community Projects","Auth.ConfirmEmailAddress":"Confirm email address","Auth.ConfirmPassword":"Confirm password","Auth.ConfirmYourPassword":"Confirm your password","Auth.Congratulations":"Congratulations!","Dict.Contact":"Contact","Events.ContactRATicketSupport":"Contact RA ticket support","Events.ContactThePromoter":"Contact the promoter","Dict.Contribute":"Contribute","Dict.CookiePolicy":"Cookie Policy","Dict.Cookies":"Cookies","Events.Cost":"Cost","Dict.Cost":"Cost","Dict.Country":"Country","Dict.CreateVenue":"Create a new venue","Dict.CurrentPlan":"Current plan","Music.MixOfTheDaySummary":"Daily mixes from the world of electronic music.","Events.Date":"Date","Dict.DateEstablished":"Date est.","Errors.DateOfBirthUnrealistic":"Date of birth is unrealistic","Errors.DateOfBirthMustBeInThePast":"Date of birth must be in the past","Auth.Day":"Day","Dict.Day":"Day","Dict.Details":"Details","Dict.Discover":"Discover","Dict.Distance":"Distance","Dict.Diversity":"Div ...
#   key: 'pk_live_Z6F2v32uJEQnwn46SLF7xdojmnOPLfAI',
#   cookieDomain: new URL('https://web.archive.org/web/20210326225933/https://ra.co').host
# })</script></body></html><!--
#      FILE ARCHIVED ON 22:59:33 Mar 26, 2021 AND RETRIEVED FROM THE
#      INTERNET ARCHIVE ON 00:49:53 Nov 19, 2021.
#      JAVASCRIPT APPENDED BY WAYBACK MACHINE, COPYRIGHT INTERNET ARCHIVE.
#
#      ALL OTHER CONTENT MAY ALSO BE PROTECTED BY COPYRIGHT (17 U.S.C.
#      SECTION 108(a)(3)).
# -->
# <!--
# playback timings (ms):
#   captures_list: 328.919
#   exclusion.robots: 0.094
#   exclusion.robots.policy: 0.087
#   RedisCDXSource: 2.434
#   esindex: 0.006
#   LoadShardBlock: 309.834 (3)
#   PetaboxLoader3.datanode: 255.323 (4)
#   CDXLines.iter: 14.36 (3)
#   load_resource: 82.156
#   PetaboxLoader3.resolve: 18.834
# -->>

# %%
# Find the container with event listings in it
events_all = soup.find('div', {'data-tracking-id':'events-all'})
events_all.prettify
# Out:
# <bound method Tag.prettify of <div class="Box-omzyfs-0 sc-AxjAm cshLAo" data-tracking-id="events-all"><div class="Box-omzyfs-0 sc-AxjAm htYgja"></div><div><ul class="Grid__GridStyled-sc-1l00ugd-0 fHKIhJ grid"><li class="Column-sc-18hsrnn-0 gnwWng"><div class="Box-omzyfs-0 fYkcJU"><div class="Box-omzyfs-0 SectionStyledBox-tvjxx0-0 eEYxFS sticky-header"><h3 class="Box-omzyfs-0 Heading__StyledBox-sc-120pa9w-0 fwuoVk"><span class="Text-sc-1t0gn2o-0 dvCBwl" color="accent" font-weight="normal"><span class="Text-sc-1t0gn2o-0 gSvLLX" color="accent" font-weight="normal"≯</span>Sat, 30 Mar</span></h3></div><hr class="Divider__HorizontalDivider-sc-1qsmuc-0 klshtO"/><ul class="Grid__GridStyled-sc-1l00ugd-0 fuNsvk grid" data-test-id="ticketed-event"><li class="Column-sc-18hsrnn-0 jHShKh"><div class="Box-omzyfs-0 sc-AxjAm dqkjhR" data-test-id="ticketed-event"><h3 class="Box-omzyfs-0 Heading__StyledBox-sc-120pa9w-0 fhMVGI"><a class="Link__AnchorWrapper-k7o46r-1 bmWkiB" data-test-id="event-listing-heading" data-tracking-id="/events/1234892" href="/web/20210326225933/https://ra.co/events/1234892"><span class="Text-sc-1t0gn2o-0 Link__StyledLink-k7o46r-0 fAmOyf" color="primary" data-test-id="event-listing-heading" data-tracking-id="/events/1234892" font-weight="normal" href="/events/1234892">UnterMania II</span></a></h3><div class="Box-omzyfs-0 sc-AxjAm jVLhoy"><span class="Text-sc-1t0gn2o-0 dWOMtb" color="primary" font-weight="normal">Mary Yuzovskaya, Manni Dee, Umfang, Juana, The Lady Machine</span></div><div class="Box-omzyfs-0 sc-AxjAm fCFvgO"><div class="Box-omzyfs-0 sc-AxjAm ebaaK"><div class="Box-omzyfs-0 sc-AxjAm fOOuYI" height="30"><div class="Box-omzyfs-0 sc-AxjAm hoMiiH" color="accent" height="24" width="24"><svg aria-label="Location" height="100%" viewbox="0 0 24 24" width="100%"><g fill="none" fill-rule="evenodd"><path d="M0 0h24v24H0z" fill="none"></path><path d="M13.613 15.075c.26-.501.505-.988.732-1.456C15.393 11.456 16 9.785 16 9a4 4 0 10-8 0c0 .785.607 2.456 1.655 4.619.227.468.472.955.732 1.456A83.615 83.615 0 0012 18.022c.55-.962 1.1-1.96 1.613-2.947zM18 9c0 1.2-.67 3.045-1.855 5.491-.236.486-.49.99-.758 1.506a86.17 86.17 0 01-2.532 4.522 1 1 0 01-1.71 0 85.564 85.564 0 01-.793-1.35 86.17 86.17 0 01-1.74-3.172 60.318 60.318 0 01-.757-1.506C6.67 12.045 6 10.201 6 9a6 6 0 016-6 6 6 0 016 6z" fill="currentColor"></path><path d="M13 9a1 1 0 11-2 0 1 1 0 112 0" fill="currentColor"></path></g></svg></div><span class="Text-sc-1t0gn2o-0 hhfigA" color="primary" font-weight="normal">TBA - New York</span></div><div class="Box-omzyfs-0 sc-AxjAm jYikCb" height="30"><div class="Box-omzyfs-0 sc-AxjAm faxXyr" color="secondary" height="24" width="24"><svg aria-label="Ticket" height="100%" viewbox="0 0 24 24" width="100%"><g fill="none" fill-rule="evenodd"><path d="M0 0h24v24H0z" fill="none"></path><path d="M8.243 6.827a1 1 0 010-1.414l2.12-2.12a1 1 0 011.415 0l8.485 8.484a1 1 0 010 1.414l-2.12 2.121a1 1 0 01-1.415 0 1 1 0 00-1.415 1.414 1 1 0 010 1.414l-2.12 2.123a1 1 0 01-1.415 0l-8.485-8.486a1 1 0 010-1.414l2.122-2.121a1 1 0 011.414 0 1.001 1.001 0 001.414-1.415zm2-.586a3.002 3.002 0 01-4 4.002l-.829.828 7.07 7.07.829-.828a3.002 3.002 0 014.001-4.001l.828-.828-7.071-7.07-.828.827z" fill="currentColor"></path></g></svg></div><a class="Link__AnchorWrapper-k7o46r-1 cIDdag" color="secondary" href="/web/20210326225933/https://ra.co/events/1234892#tickets"><span class="Text-sc-1t0gn2o-0 Link__StyledLink-k7o46r-0 iHZuSI" color="secondary" font-weight="normal" href="/events/1234892#tickets"><span class="Box-omzyfs-0 kMopVb" display="[object Object]">RA</span><span class="Box-omzyfs-0 fQMHMH" display="[object Object]">RA Tickets</span></span></a></div></div><div class="Box-omzyfs-0 sc-AxjAm jYikCb" height="30"><div class="Box-omzyfs-0 sc-AxjAm hoMiiH" color="accent" height="24" width="24"><svg aria-label="Person" height="100%" viewbox="0 0 24 24" width="100%"><g fill="none" fill-rule="evenodd"><path d="M0 0h24v24H0z" fill="none"></path><path d="M14 ...

# %%
# Find a list of events by date within that container
events_list = events_all.find('ul').find('li')

# %%
events_list.text[:150]
# Out:
# '̸Sat, 30 MarUnterMania IIMary Yuzovskaya, Manni Dee, Umfang, Juana, The Lady MachineTBA - New YorkRARA Tickets457Cocoon New York: Sven Väth, Ilario Al'

# %%
events_by_dates = events_list.findChildren(recursive=False)

# %%
events_by_dates[0].text[:100]
# Out:
# '̸Sat, 30 MarUnterMania IIMary Yuzovskaya, Manni Dee, Umfang, Juana, The Lady MachineTBA - New YorkRA'

# %%
events_by_dates[1].text
# Out:
# ''

# %%
events_by_dates[2].text[:100]
# Out:
# '̸Sun, 31 MarSunday: Soul SummitNowadaysRARA Tickets132New Dad & Aaron Clark (Honcho)Aaron Clark, New'

# %%
date = events_by_dates[0].find("div", class_="sticky-header").text
date
# Out:
# '̸Sat, 30 Mar'

# %%
# Extract the name, venue, and number of attendees from one of the
# events within that container
event = events_by_dates[0].findChildren('ul')
event[0].text
# Out:
# 'UnterMania IIMary Yuzovskaya, Manni Dee, Umfang, Juana, The Lady MachineTBA - New YorkRARA Tickets457'

# %%
name = event[0].find("h3").text
name
# Out:
# 'UnterMania II'

# %%
venue_and_attendees = event[0].findAll("div", {"height": 30})

# %%
venue = venue_and_attendees[0].text
venue
# Out:
# 'TBA - New York'

# %%
len(venue_and_attendees)
# Out:
# 3

# %%
attend = venue_and_attendees[-1].text
attend
# Out:
# '457'

# %%
print("Name -", name)
print("Venue -", venue)
print("Date -", date.strip("'̸"))
print("Attendence -", attend)
# Out:
# Name - UnterMania II
# Venue - TBA - New York
# Date - Sat, 30 Mar
# Attendence - 457

# %%
# Loop over all of the event entries, extract this information
# from each, and assemble a dataframe

rows = []

for event_date in events_by_dates:
    if not event_date.text:
        continue
    date = event_date.find("div", class_="sticky-header").text
    date = date.strip("'̸")
    events = event_date.findChildren('ul')
    for event in events:
        name = event.find("h3").text
        venue_and_attendees = event.findAll("div", {"height": 30})
        venue = venue_and_attendees[0].text   
        if len(venue_and_attendees) == 3:
            num_attendees = int(venue_and_attendees[-1].text)
        else:
            num_attendees = np.nan
        rows.append([name, venue, date, num_attendees])
    
    
df = pd.DataFrame(rows)
df.head()
# Out:
#                                                    0               1  \
# 0                                      UnterMania II  TBA - New York
# 1  Cocoon New York: Sven Väth, Ilario Alicante, B...    99 Scott Ave
# 2              Horse Meat Disco - New York Residency       Elsewhere
# 3             Rave: Underground Resistance All Night        Nowadays
# 4  Believe You Me // Beta Librae, Stephan Kimbel,...  TBA - New York
#
#              2      3
# 0  Sat, 30 Mar  457.0
# 1  Sat, 30 Mar  407.0
# 2  Sat, 30 Mar  375.0
# 3  Sat, 30 Mar  232.0
# 4  Sat, 30 Mar   89.0

# %%
len(df)
# Out:
# 119

# %%
# Bring it all together in a function that makes the request, gets the
# list of entries from the response, loops over that list to extract the
# name, venue, date, and number of attendees for each event, and returns
# that list of events as a dataframe

def scrape_events(events_page_url):
    #Your code here
    html_page = requests.get(events_page_url) 
    soup = BeautifulSoup(html_page.content, 'html.parser')
    events_all = soup.find('div', attrs={'data-tracking-id':'events-all'})
    events_list = events_all.find('ul').find('li')
    events_by_dates = events_list.findChildren(recursive=False)
    rows = []
    for event_date in events_by_dates:
        if not event_date.text:
            continue
        date = event_date.find("div", class_="sticky-header").text
        date = date.strip("'̸")
        events = event_date.findChildren('ul')
        for event in events:
            name = event.find("h3").text
            venue_and_attendees = event.findAll("div", attrs={"height": 30})
            venue = venue_and_attendees[0].text   
            if len(venue_and_attendees) == 3:
                num_attendees = int(venue_and_attendees[-1].text)
            else:
                num_attendees = np.nan
            rows.append([name, venue, date, num_attendees])
    df = pd.DataFrame(rows)
    df.columns = ["Event_Name", "Venue", "Event_Date", "Number_of_Attendees"]
    return df

# %%
# Test out your function
scrape_events(EVENTS_PAGE_URL)
# Out:
#                                             Event_Name  \
# 0                                        UnterMania II
# 1    Cocoon New York: Sven Väth, Ilario Alicante, B...
# 2                Horse Meat Disco - New York Residency
# 3               Rave: Underground Resistance All Night
# 4    Believe You Me // Beta Librae, Stephan Kimbel,...
# ..                                                 ...
# 114                               A Night at the Baths
# 115                                        Blaqk Audio
# 116                                     Erik the Lover
# 117                                    Wax On Vissions
# 118            Schimanski & Good Looks present: Mercer
#
#                           Venue   Event_Date  Number_of_Attendees
# 0                TBA - New York  Sat, 30 Mar                457.0
# 1                  99 Scott Ave  Sat, 30 Mar                407.0
# 2                     Elsewhere  Sat, 30 Mar                375.0
# 3                      Nowadays  Sat, 30 Mar                232.0
# 4                TBA - New York  Sat, 30 Mar                 89.0
# ..                          ...          ...                  ...
# 114             C'mon Everybody   Fri, 5 Apr                  NaN
# 115  Music Hall of Williamsburg   Fri, 5 Apr                  NaN
# 116                       Erv's   Fri, 5 Apr                  NaN
# 117                   Starliner   Fri, 5 Apr                  NaN
# 118                  Schimanski   Fri, 5 Apr                  NaN
#
# [119 rows x 4 columns]

# %% [markdown]
# ## Write a Function to Retrieve the URL for the Next Page
#
# As you scroll down, there should be a button labeled "Next Week" that will take you to the next page of events. Write code to find that button and extract the URL from it.
#
# This is a relative path, so make sure you add `https://web.archive.org` to the front to get the URL.
#
# ![next page](images/ra_next.png)

# %%
# Find the button, find the relative path, create the URL for the current `soup`
buttons = soup.find("div", attrs={"aria-hidden": 'true'})
buttons
# Out:
# <div aria-hidden="true" class="Box-omzyfs-0 sc-AxjAm Panel__StyledAlignment-sc-1udo2qh-0 ArchiveNavigator___StyledPanel-x733n4-1 gUdql"><a class="ArchiveNavigator__StyledLink-x733n4-0 fXcSbA" data-tracking-id="/events/us/newyork?week=2019-03-23" href="/web/20210326225933/https://ra.co/events/us/newyork?week=2019-03-23">Sat, 23 Mar</a><div class="Box-omzyfs-0 sc-AxjAm NavigationItem___StyledAlignment-t52po1-0 iHjmUI"><span class="Text-sc-1t0gn2o-0 dtYoLc" color="secondary" font-weight="normal">Previous week</span><div class="Box-omzyfs-0 sc-AxjAm fsoYzJ" width="100%"><a class="Link__AnchorWrapper-k7o46r-1 bmWkiB" data-tracking-id="/events/us/newyork?week=2019-03-23" display="block" href="/web/20210326225933/https://ra.co/events/us/newyork?week=2019-03-23"><span class="Text-sc-1t0gn2o-0 Link__StyledLink-k7o46r-0 eIXPIq" color="primary" data-tracking-id="/events/us/newyork?week=2019-03-23" display="block" font-weight="normal" href="/events/us/newyork?week=2019-03-23">Sat, 23 Mar</span></a><div class="Box-omzyfs-0 sc-AxjAm dQKRnM" color="primary" height="24" width="24"><svg aria-label="Left arrow" height="100%" viewbox="0 0 24 24" width="100%"><g fill="none" fill-rule="evenodd"><path d="M0 0h24v24H0z" fill="none"></path><path d="M15.707 17.293a1 1 0 01-1.414 1.414l-6-6a1 1 0 010-1.414l6-6a1 1 0 011.414 1.414L10.414 12l5.293 5.293z" fill="currentColor"></path></g></svg></div></div></div></div>

# %%
next_arrow = soup.find("svg", attrs={"aria-label": "Right arrow"})
next_arrow
# Out:
# <svg aria-label="Right arrow" height="100%" viewbox="0 0 24 24" width="100%"><g fill="none" fill-rule="evenodd"><path d="M0 0h24v24H0z" fill="none"></path><path d="M8.293 6.707a1 1 0 011.414-1.414l6 6a1 1 0 010 1.414l-6 6a1 1 0 11-1.414-1.414L13.586 12 8.293 6.707z" fill="currentColor"></path></g></svg>

# %%
next_arrow.parent
# Out:
# <div class="Box-omzyfs-0 sc-AxjAm dQKRnM" color="primary" height="24" width="24"><svg aria-label="Right arrow" height="100%" viewbox="0 0 24 24" width="100%"><g fill="none" fill-rule="evenodd"><path d="M0 0h24v24H0z" fill="none"></path><path d="M8.293 6.707a1 1 0 011.414-1.414l6 6a1 1 0 010 1.414l-6 6a1 1 0 11-1.414-1.414L13.586 12 8.293 6.707z" fill="currentColor"></path></g></svg></div>

# %%
link = next_arrow.parent.previous_sibling

# %%
next_page = link.get("href")

# %%
next_page_url = "https://web.archive.org" + next_page
next_page_url
# Out:
# 'https://web.archive.org/web/20210326225933/https://ra.co/events/us/newyork?week=2019-04-06'

# %%
# Fill in this function, to take in the current page's URL and return the
# next page's URL
def next_page(url):
    #Your code here
    next_arrow = soup.find("svg", attrs={"aria-label": "Right arrow"})
    link = next_arrow.parent.previous_sibling
    next_page = link.get("href")
    next_page_url = "https://web.archive.org" + next_page
    return next_page_url

# %%
# Test out your function
next_page(EVENTS_PAGE_URL)
# Out:
# 'https://web.archive.org/web/20210326225933/https://ra.co/events/us/newyork?week=2019-04-06'

# %% [markdown]
# ## Scrape the Next 500 Events
#
# In other words, repeatedly call `scrape_events` and `next_page` until you have assembled a dataframe with at least 500 rows.
#
# Display the data sorted by the number of attendees, greatest to least.
#
# We recommend adding a brief `time.sleep` call between `requests.get` calls to avoid rate limiting.

# %%
import time

# %%
# Your code here
concert_df = pd.DataFrame()
current_page = EVENTS_PAGE_URL

while len(concert_df) <= 500:
    scrap = scrape_events(current_page)
    time.sleep(1)
    concert_df = pd.concat([concert_df, scrap])
    current_page = next_page(current_page)
    time.sleep(1)
    
concert_df
# Out:
#                                             Event_Name                  Venue  \
# 0                                        UnterMania II         TBA - New York
# 1    Cocoon New York: Sven Väth, Ilario Alicante, B...           99 Scott Ave
# 2                Horse Meat Disco - New York Residency              Elsewhere
# 3               Rave: Underground Resistance All Night               Nowadays
# 4    Believe You Me // Beta Librae, Stephan Kimbel,...         TBA - New York
# ..                                                 ...                    ...
# 111   Gavin Rayna Russom, Sybil Jason, Fougere & Perrx  Bossa Nova Civic Club
# 112    Lqqk Studio with DJ Healthy x Dondero x DJ Fire         Black Flamingo
# 113                           I Feel: Superhero Utopia         TBA - New York
# 114  SUB:MERGE Presents: Sunk:. VI - SUB:Merge vs K...              Sunnyvale
# 115            House Music Happy Hour with DJ Mkhuseli   Bean & Barley Harlem
#
#       Event_Date  Number_of_Attendees
# 0    Sat, 30 Mar                457.0
# 1    Sat, 30 Mar                407.0
# 2    Sat, 30 Mar                375.0
# 3    Sat, 30 Mar                232.0
# 4    Sat, 30 Mar                 89.0
# ..           ...                  ...
# 111  Fri, 12 Apr                  NaN
# 112  Fri, 12 Apr                  NaN
# 113  Fri, 12 Apr                  NaN
# 114  Fri, 12 Apr                  NaN
# 115  Fri, 12 Apr                  NaN
#
# [583 rows x 4 columns]

# %%
concert_df.sort_values("Number_of_Attendees", ascending=False)
# Out:
#                                             Event_Name  \
# 0                      Zero presents... The Masquerade
# 0                      Zero presents... The Masquerade
# 0                      Zero presents... The Masquerade
# 0                      Zero presents... The Masquerade
# 89                     Stavroz live! presented by Zero
# ..                                                 ...
# 111   Gavin Rayna Russom, Sybil Jason, Fougere & Perrx
# 112    Lqqk Studio with DJ Healthy x Dondero x DJ Fire
# 113                           I Feel: Superhero Utopia
# 114  SUB:MERGE Presents: Sunk:. VI - SUB:Merge vs K...
# 115            House Music Happy Hour with DJ Mkhuseli
#
#                       Venue   Event_Date  Number_of_Attendees
# 0                  The 1896   Sat, 6 Apr                919.0
# 0                  The 1896   Sat, 6 Apr                919.0
# 0                  The 1896   Sat, 6 Apr                919.0
# 0                  The 1896   Sat, 6 Apr                919.0
# 89   The Williamsburg Hotel  Fri, 12 Apr                481.0
# ..                      ...          ...                  ...
# 111   Bossa Nova Civic Club  Fri, 12 Apr                  NaN
# 112          Black Flamingo  Fri, 12 Apr                  NaN
# 113          TBA - New York  Fri, 12 Apr                  NaN
# 114               Sunnyvale  Fri, 12 Apr                  NaN
# 115    Bean & Barley Harlem  Fri, 12 Apr                  NaN
#
# [583 rows x 4 columns]

# %% [markdown]
# ## Summary
#
# Congratulations! In this lab, you successfully developed a pipeline to scrape a website for concert event information!
